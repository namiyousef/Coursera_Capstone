# %% [markdown]
# # FinalCapstone_3_ClusteringNeighbourhoods_2
#
# This is a notebook that contains the analysis for the first part of "What is the best neighbourhood to live in as a student at Imperial College London?" (*link:* https://github.com/namiyousef/Coursera_Capstone).
#
# **NOTE:** if you are a peer examiner from the IBM Coursera course (IBM Applied Data Science Capstone), please only mark this notebook, and the relevant parts of the report. At this current time, I will not be able to complete the second part of the project (stated in my report).
#
# **Notes from previous notebook:**
# - previous notebook found that the dataset for the average age is not too useful. Though at first this appeared to be problematic, it was actually beneficial as it informed our decision: was age really an important factor?
# - this notebook will now continue analysis

# %% [markdown]
# # 0 - Libraries needed, configuration

# %%
""" Libraries """

# file management and web scraping
import os
import urllib.request
try: 
    from BeautifulSoup import BeautifulSoup
except ImportError:
    from bs4 import BeautifulSoup

# mathematical

# data exploration
import pandas as pd
import numpy as np

# visualisation
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.cm as cm
import folium
from geopy.geocoders import Nominatim

# preprocessing

# modelling

# evaluation

""" Configuration """

# pandas
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Data Cleaning

# %%
df_crime = pd.read_csv(('/Users/yousefnami/Desktop/Yousef/PrivateTings/My Stuff/Courses'
        '/IBMDataScienceCertificate/CapstoneProject/Capstone/Coursera_Capstone/Data/df_crime.csv'),index_col = 0)
df_rent = pd.read_csv(('/Users/yousefnami/Desktop/Yousef/PrivateTings/My Stuff/Courses'
        '/IBMDataScienceCertificate/CapstoneProject/Capstone/Coursera_Capstone/Data/df_rent.csv'),index_col = 0)

print(df_crime.shape,df_rent.shape)
# Out:
# /Users/yousefnami/opt/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# (3320519, 7) (174, 8)

# %%
df_crime.head()
# Out:
#      Month  Longitude   Latitude                   Location  \
# 0  2020-01  -0.539301  50.817200  On or near Highdown Drive
# 1  2020-01   0.137065  51.583672  On or near Police Station
# 2  2020-01   0.134947  51.588063      On or near Mead Grove
# 3  2020-01   0.137065  51.583672  On or near Police Station
# 4  2020-01   0.137065  51.583672  On or near Police Station
#
#                    LSOA name             Crime type  files
# 0                  Arun 009F            Other theft      1
# 1  Barking and Dagenham 001A  Anti-social behaviour      1
# 2  Barking and Dagenham 001A  Anti-social behaviour      1
# 3  Barking and Dagenham 001A  Anti-social behaviour      1
# 4  Barking and Dagenham 001A  Anti-social behaviour      1

# %%
df_rent.head()
# Out:
#            Place  Studio  One Bed  Two Beds  Three Beds  Four Beds  Five Beds  \
# 0        Bromley     NaN    263.0     287.0       381.0      498.0        NaN
# 1         Croyon   197.0    280.0     355.0         NaN        NaN        NaN
# 2  Bethnal Green   292.0    370.0     461.0       583.0      622.0        NaN
# 3            Bow     NaN    313.0     371.0       481.0      612.0      637.0
# 4   Canary Wharf   405.0    507.0     585.0       719.0        NaN        NaN
#
#   PostDist
# 0      BR1
# 1      CR0
# 2       E2
# 3       E3
# 4      E14

# %%
# exlore
def strip_index(string):
    if (isinstance(string,str)):
        string = string[:-4]
    return string

df_crime.rename(columns = {'LSOA name':'PostDist'},inplace = True)

df_crime.PostDist = df_crime.PostDist.apply(lambda x: strip_index(x))

df_crime.head()
# Out:
#      Month  Longitude   Latitude                   Location  \
# 0  2020-01  -0.539301  50.817200  On or near Highdown Drive
# 1  2020-01   0.137065  51.583672  On or near Police Station
# 2  2020-01   0.134947  51.588063      On or near Mead Grove
# 3  2020-01   0.137065  51.583672  On or near Police Station
# 4  2020-01   0.137065  51.583672  On or near Police Station
#
#                 PostDist             Crime type  files
# 0                  Arun             Other theft      1
# 1  Barking and Dagenham   Anti-social behaviour      1
# 2  Barking and Dagenham   Anti-social behaviour      1
# 3  Barking and Dagenham   Anti-social behaviour      1
# 4  Barking and Dagenham   Anti-social behaviour      1

# %%
from time import sleep

df_crime.reset_index(inplace = True)
df_crime.dropna(axis = 0, inplace = True)
df_crime.set_index('PostDist',inplace = True)

geolocator = Nominatim(user_agent="foursquare_agent")
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut

def do_geocode(address):
    geopy = Nominatim(user_agent="foursquare_agent")
    try:
        return geopy.geocode(address)
    except GeocoderTimedOut:
        return do_geocode(address)

for Place in df_crime.index.unique():
    #location = geolocator.geocode('{} United Kingdom'.format(Place))
    location = do_geocode('{} United Kingdom'.format(Place))
    sleep(1)
    address = location.address.split(', ')
    if 'London' in location.address and address[-2] != 'England':
        #print(location)


        if address[-2].split(' ')[0] not in df_rent.PostDist.unique():
            df_crime = df_crime[[Place not in value for value in df_crime.index.values]]
        else:
            print(location)
# Out:
# Bromley, London, Greater London, England, BR1 1EY, United Kingdom
# Camden Town, London, Greater London, England, NW1 9PJ, United Kingdom
# Croydon, London, Greater London, England, CR0 1SZ, United Kingdom
# Ealing, London Borough of Ealing, London, Greater London, England, W5 5DG, United Kingdom
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     156             conn = connection.create_connection(
# --> 157                 (self._dns_host, self.port), self.timeout, **extra_kw
#     158             )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375         try:
# --> 376             self._validate_conn(conn)
#     377         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     993         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994             conn.connect()
#     995
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     299         # Add certificate verification
# --> 300         conn = self._new_conn()
#     301         hostname = self.host
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     163                 "Connection to %s timed out. (connect timeout=%s)"
# --> 164                 % (self.host, self.timeout),
#     165             )
#
# ConnectTimeoutError: (<urllib3.connection.VerifiedHTTPSConnection object at 0x11e2c5b10>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)')
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     759                 body_pos=body_pos,
# --> 760                 **response_kw
#     761             )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     435         if new_retry.is_exhausted():
# --> 436             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     437
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=East+Hertfordshire++United+Kingdom&format=json&limit=1 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x11e2c5b10>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     382         try:
# --> 383             resp = self.session.get(url, timeout=timeout, headers=headers)
#     384         except Exception as error:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     503                 if not isinstance(e.reason, NewConnectionError):
# --> 504                     raise ConnectTimeout(e, request=request)
#     505
#
# ConnectTimeout: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=East+Hertfordshire++United+Kingdom&format=json&limit=1 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x11e2c5b10>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# <ipython-input-17-35db67f46f7a> in <module>
#      18 for Place in df_crime.index.unique():
#      19     #location = geolocator.geocode('{} United Kingdom'.format(Place))
# ---> 20     location = do_geocode('{} United Kingdom'.format(Place))
#      21     sleep(1)
#      22     address = location.address.split(', ')
#
# <ipython-input-17-35db67f46f7a> in do_geocode(address)
#      12     geopy = Nominatim(user_agent="foursquare_agent")
#      13     try:
# ---> 14         return geopy.geocode(address)
#      15     except GeocoderTimedOut:
#      16         return do_geocode(address)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/geopy/geocoders/nominatim.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded, featuretype, namedetails)
#     292         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     293         callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 294         return self._call_geocoder(url, callback, timeout=timeout)
#     295
#     296     def reverse(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     358         try:
#     359             if is_json:
# --> 360                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     361             else:
#     362                 result = self.adapter.get_text(url, timeout=timeout, headers=req_headers)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/geopy/adapters.py in get_json(self, url, timeout, headers)
#     371
#     372     def get_json(self, url, *, timeout, headers):
# --> 373         resp = self._request(url, timeout=timeout, headers=headers)
#     374         try:
#     375             return resp.json()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     393                     raise GeocoderServiceError(message)
#     394                 else:
# --> 395                     raise GeocoderUnavailable(message)
#     396             elif isinstance(error, requests.Timeout):
#     397                 raise GeocoderTimedOut("Service timed out")
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /search?q=East+Hertfordshire++United+Kingdom&format=json&limit=1 (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x11e2c5b10>, 'Connection to nominatim.openstreetmap.org timed out. (connect timeout=1)'))

# %%
print(df_crime.shape)
df_crime.head()
# Out:
# (2428645, 7)
#                        index    Month  Longitude   Latitude  \
# PostDist
# Arun                       0  2020-01  -0.539301  50.817200
# Barking and Dagenham       1  2020-01   0.137065  51.583672
# Barking and Dagenham       2  2020-01   0.134947  51.588063
# Barking and Dagenham       3  2020-01   0.137065  51.583672
# Barking and Dagenham       4  2020-01   0.137065  51.583672
#
#                                         Location             Crime type  files
# PostDist
# Arun                   On or near Highdown Drive            Other theft      1
# Barking and Dagenham   On or near Police Station  Anti-social behaviour      1
# Barking and Dagenham       On or near Mead Grove  Anti-social behaviour      1
# Barking and Dagenham   On or near Police Station  Anti-social behaviour      1
# Barking and Dagenham   On or near Police Station  Anti-social behaviour      1

# %% [markdown]
# # Conclusion
#
#
# **Note:** if you'd like to reproduce this project, please ensure that you select the correct police force. Selecting both Metropolitan and Greater London area does not yield nice results
